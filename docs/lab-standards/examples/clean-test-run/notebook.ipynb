# %% [markdown]
# # Example Compact Test Notebook
#
# Loads run metrics from `runs/*/metrics.json`.

# %%
import json
from pathlib import Path

metrics = [json.loads(path.read_text()) for path in sorted(Path('runs').glob('*/metrics.json'))]
metrics
